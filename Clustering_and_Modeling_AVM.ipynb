# %% [markdown]
# # Cluster data and feed to AVM prediction models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import os

# %%
# navigate to local repo
os.chdir('/users/trevor.mattos/desktop/nycdsa/finalproject/cleancode')

# %% [markdown]
# ### Read the clean merged data

# %%
# from data_compiler import *
# df=mycompiler()

# %%
# produce the original clean merged df with the code cell above
# then save as csv to reduce computation time using this cell

# df.to_csv(
#     '/users/trevor.mattos/desktop/nycdsa/finalproject/cleancode/data/compiled.csv',
# index=False)

# %%
# read data from file
df=pd.read_csv('./data/compiled.csv')

# %%
# recast categorical columns as object 
    # to ensure that reading the CSV doesn't affect our analysis
for i in ['special_features',
          'transaction_type',
          'listing_status',
          'listing_special_features',
          'zip']:
    df[i]=df[i].astype(object)

# %% [markdown]
# ### Reduce dimensionality with PCA

# %%
from pca_optimized import *
df_var, pca_loadings, components=mypca(df, n_components=3)

# %%
# check the components' exlained variance 
df_var
# Out:
# array([0.38979099, 0.10758053, 0.08565046])

# %%
# view loading vectors
pca_loadings
# Out:
#                                         pc1       pc2       pc3
# beds                              -0.080432  0.437244  0.260843
# baths_full                        -0.095839  0.441851  0.322040
# square_footage                    -0.092703  0.407998  0.305276
# year_built                        -0.146979  0.133285  0.282095
# grocer_dist                       -0.006645 -0.336528  0.269479
# bank_dist                         -0.065362 -0.252643  0.396339
# school_dist                       -0.058896 -0.262502  0.435359
# walkscore                          0.160847  0.222933 -0.184259
# violent_crime_total_rate           0.296688 -0.014451  0.033821
# violent_crime_assault_rate         0.262411 -0.065645  0.065679
# violent_crime_robbery_rate         0.291502  0.053366 -0.019313
# violent_crime_rape_rate            0.291514  0.018152  0.055339
# violent_crime_murder_rate          0.263237  0.128363 -0.034699
# property_crime_total_rate          0.264132  0.030785  0.077655
# property_crime_theft_rate          0.208774  0.027159  0.069283
# property_crime_vehicle_theft_rate  0.253430  0.137593 -0.003862
# property_crime_burglary_rate       0.262809 -0.094878  0.125317
# property_crime_arson_rate          0.171651  0.209914  0.003712
# other_crime_total_rate             0.214104 -0.079253  0.218583
# other_crime_kidnapping_rate        0.258226  0.106784 -0.013424
# other_crime_drug_crimes_rate       0.213126 -0.012548  0.086286
# other_crime_vandalism_rate         0.177002 -0.086441  0.218915
# other_crime_identity_theft_rate    0.071673 -0.079688  0.246049
# other_crime_animal_cruelty_rate    0.232033 -0.064447 -0.041943

# %%
# save components into a dataframe
df_pca=pd.DataFrame(components, columns=['pc1','pc2','pc3'])
df_pca
# Out:
#             pc1       pc2       pc3
# 0     -0.772738 -2.637952  2.006469
# 1      2.983391 -1.683634  0.195053
# 2      2.964482 -1.690154  0.201208
# 3      2.889888 -0.707172  0.404453
# 4      2.542239 -0.061526  1.401968
# ...         ...       ...       ...
# 11486 -1.219903 -0.640894  2.171864
# 11487  0.218796 -1.531675 -1.332892
# 11488 -0.222348 -1.677375  0.296606
# 11489 -0.035737 -1.398951 -0.899497
# 11490  0.343878 -2.323755 -1.422191
#
# [11491 rows x 3 columns]

# %% [markdown]
# ### Cluster data using principal components

# %%
from sklearn.cluster import KMeans
kmeans = KMeans()

# %%
kmeans.set_params(n_clusters=3)
kmeans.fit(df_pca)
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# ### Visualize clusters in 3d space

# %%
df_pca['clusters']=(kmeans.labels_.reshape(-1,1))

# %%
# create function
def coloring(clusters):
    if clusters==0:
        return '#3498DB'
    elif clusters==1:
        return '#17A589'
    elif clusters==2:
        return '#C39BD3'
    
# create new column
df_pca['color']=df_pca['clusters'].apply(coloring)

# %%
import plotly.graph_objects as go # for data visualization
import plotly.express as px # for data visualization

# %%
# Create a 3D scatter plot
fig = px.scatter_3d(df_pca, x=df_pca['pc1'], y=df_pca['pc2'],z=df_pca['pc3'],
                    opacity=0.3,
                    color=df_pca['color'],
                    color_discrete_sequence=['#3498DB','#17A589','#C39BD3'],
                    height=700, width=700)


# Update marker size
fig.update_traces(marker=dict(size=2))

fig.show()
# Out:
# <div>                            <div id="834a944a-a411-4db1-82c5-df8d1fd5e7cb" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("834a944a-a411-4db1-82c5-df8d1fd5e7cb")) {                    Plotly.newPlot(                        "834a944a-a411-4db1-82c5-df8d1fd5e7cb",                        [{"hovertemplate":"color=#17A589<br>pc1=%{x}<br>pc2=%{y}<br>pc3=%{z}<extra></extra>","legendgroup":"#17A589","marker":{"color":"#3498DB","opacity":0.3,"symbol":"circle","size":2},"mode":"markers","name":"#17A589","scene":"scene","showlegend":true,"x":[-0.7727378505629707,-0.23289414213395668,-0.3570857379867564,-0.6633230513212989,-0.39667680230261665,-1.8389162304378377,-2.075437968767395,-1.7212194304451969,-0.4443091876179422,-1.1596047977124757,-1.576648932397414,-1.7218059182573304,-1.888197413558951,-1.6143672850239887,-1.5655358556828634,-1.5510398440491324,-1.9904809101238228,-2.0106116133761964,-1.9869454791207641,-1.9947084888969708,-1.9736609795098006,-1.6443804115995004,-2.221926515438279,-1.4511959061112738,-1.5865428999037545,-1.5214093528860713,-1.317242355169614,-1.8433997550554115,-2.3715234513517003,-1.7195998122819287,-1.7195998122819287,-2.5893470349331684,-2.5802870639012623,-2.576026652100501,-1.590612005946404,-1.5031724051261826,-2.6337952222648227,-2.212488579809418,-2.1826634255599755,-2.2687990684530277,-1.5231349593684784,-2.0891048756558144,-2.987631244945472,-2.987631244945472,-1.4302764326986506,-2.4984260069147246,-2.089721699211807,-2.235598004658299,-2.2022969916294395,-2.463188120794666,-1.2577029797563042,-2.2319272806758153,-1.7996575939822332,-1.8540537743873162,-1.728401440584575,-1.728401440584575,-2.3392068572461544,-1.7443993702918195,-1.497415894308829,-2.2551641425925193,-1.4319919773996979,-2.300135082918824,-1.602459747817086,-1.6218617067940588,-1.522224575374096,-1.5245660716343672,-0.9443244369997013,-1.3778285456318236,-1.542851848630951,-2.243352082306435,-2.3213796272713316,-1.6034939947096354,-2.37508296248682,-2.696285693410927,-2.0522923565383957,-2.1272575498038173,-2.7097662501274087,-2.6170136727251627,-2.6181593257377873,-1.534015718380533,-2.644267414920778,-1.6974893828236743,-2.3885202575695015,-2.5155375438540326,-2.8805891967175388,-1.499584737672301,-2.144657455463789,-2.8154996733115536,-1.2910855541243778,-3.0059784243641094,-3.0059784243641094,-1.4875442147666251,-1.4608309262369004,-2.211529552687544,-1.7779028814106457,-2.9863898836314844,-2.1542552183003836,-1.7018325997077508,-1.2307424304321368,-1.2307712705215412,-2.630252282397468,-2.630252282397468,-1.5525633725560661,-1.4348320758540765,-2.2964683488540327,-1.7169987543103757,-2.319239897036524,-1.7169987543103757,-1.8096433120562239,-2.887678283899259,-2.981544096633682,-2.981544096633682,-1.2244709616318046,-2.949929483938948,-1.7647068989832189,-1.527948505093979,-0.9783510149193574,-2.579652368380922,-2.3764476224341453,-2.972653961921534,-1.5384171137021616,-2.981544096633682,-2.3366350451909454,-1.5364234933365226,-2.4858746988712292,-2.453918709438786,-1.4490337482742817,-1.7607066293201976,-1.8613749271618651,-1.762119427067734,-1.704993941494392,-1.7234174816490466,-1.965579621061154,-1.9608638899648057,-2.3086550029131416,-2.8773986190695813,-2.6707460904022264,-2.6574174814266502,-2.4777492912201504,-2.503319499343785,-1.646257302341723,-1.6286128061457277,-2.488957398383911,-2.489077613676002,-2.48919857266658,-2.489298918045155,-1.3154385334982943,-0.42717227347169706,-2.4747651966742583,-2.546672272321555,-0.9819375773461045,-0.8173907669646447,-1.6628518062662683,-1.742924916516699,-1.4275955088531886,-2.2225410508751424,-1.8362156741886786,-1.844372921175299,-2.3886497173162082,-0.6861410110172276,-1.1764615861921808,-1.6679128132720331,-2.6560829939921016,-3.01551 ...

# %% [markdown]
# #### Add cluster column to original dataframe to export for EDA

# %%
df['clusters']=(kmeans.labels_.reshape(-1,1))

# %%
df.to_csv('./data/clustered.csv',index=False)

# %% [markdown]
# # Predict prices using clusters

# %% [markdown]
# #### Create a separate object with target

# %%
target=df['price']

# %% [markdown]
# #### Drop price from dataframe

# %%
df=df.drop(['price'], axis=1)

# %% [markdown]
# #### Drop non-numeric  features

# %%
numers=[]
for col in df.columns[2:]:
    if df[col].dtype==('float64') or df[col].dtype==('int64') or\
    df[col].dtype==('int32'):
        numers.append(col)
df=df[numers]

# %% [markdown]
# #### Add cluster label

# %%
df['clusters']=(kmeans.labels_.reshape(-1,1))

# %% [markdown]
# #### Use clusterTrainTestSplit to obtain :
# * dictionary of train test split pairs for each cluster
# * list of names of train test split per cluster dataframes
# * X_train for full dataframe
# * y_train for full dataframe
# * X_test for full dataframe
# * y_test for full dataframe

# %%
from clusterTrainTestSplit import *

# %%
# assign output and specificy arguments: dataframe, target, number of clusters
dataframes, dlist, X_train, y_train, X_test,y_test=clusterTrainTestSplit(df, target, c=3)

# %% [markdown]
# # Fit Random Forest Regression model to assess performance of clustered prediction

# %% [markdown]
# #### Create function to fit Random Forest Regression models for each cluster:

# %%
def ClusterRF(dataframes,dlist):
    from sklearn.ensemble import RandomForestRegressor
    rf = RandomForestRegressor(n_estimators = 100, random_state = 0,max_depth=4)
    trainscores=[]
    testscores=[]
    clusters=[]
    for i in dlist:
        rf.fit(dataframes[i[0]], dataframes[i[1]])
        trainscores.append('The training score is: %f'\
                      # %rf.score(dataframes[i[0]], dataframes[i[1]]))
        testscores.append('The test score is: %f'\
                      # %rf.score(dataframes[i[2]], dataframes[i[3]]))
        clusters.append('Cluster: %d' %(int(i[0][-1])))
    results=list(zip(clusters,trainscores,testscores))
    return(results)

# %% [markdown]
# #### Use ClusterRF function and save results

# %%
myresults=ClusterRF(dataframes,dlist)
myresults
# Out:
# [('Cluster: 0',
#   'The training score is: 0.607415',
#   'The test score is: 0.552414'),
#  ('Cluster: 1',
#   'The training score is: 0.538973',
#   'The test score is: 0.517075'),
#  ('Cluster: 2',
#   'The training score is: 0.906605',
#   'The test score is: 0.637252')]

# %% [markdown]
# #### Obtain mean training score and test score for random forest cluster models

# %%
avgtstscores=[]
avgtrnscores=[]
for i in myresults:
    avgtstscores.append(float(i[2][-8:]))
    avgtrnscores.append(float(i[1][-8:]))
print('The average cluster training score is %f' %np.mean(avgtrnscores))
print('The average cluster test score is %f' %np.mean(avgtstscores))
# Out:
# The average cluster training score is 0.684331
# The average cluster test score is 0.568914

# %% [markdown]
# ### Fit Random Forest Regression model on overall training and test data to compare against performance of clustered prediction models

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 0, max_depth=4)
rf.fit(X_train,y_train)
print('The overall training score is %f' %rf.score(X_train,y_train))
print('The overall test score is %f' %rf.score(X_test,y_test))
# Out:
# The overall training score is 0.544914
# The overall test score is 0.539609
